# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Sapna\Downloads\Instagram_reach_Analysis\Instagram data.csv', engine='python', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB

# %%
df
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# ...

# %%
df.tail()
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# 114         2      38    373              73       80
# 115         4       1    148              20       18
# 116         0       1     92              34       10
# 117         2      75    549             148      214
# 118         5      26    443             611      228
#
#                                                Caption  \
# 114  Here are some of the best data science certifi...
# 115  Clustering is a machine learning technique use...
# ...

# %%
df.shape
#check the shape of the data
# Out:
# (119, 13)

# %%
df.columns
# Out:
# Index(['Impressions', 'From Home', 'From Hashtags', 'From Explore',
#        'From Other', 'Saves', 'Comments', 'Shares', 'Likes', 'Profile Visits',
#        'Follows', 'Caption', 'Hashtags'],
#       dtype='object')

# %%
df.index
#check rows
# Out:
# RangeIndex(start=0, stop=119, step=1)

# %% [markdown]
# # Observations
#
# *This data is about social media (Instagram post )
# *Total 119 records are present in data set
# *Out of 13 columns 11 columns are integer and 2 columns are textual
# *No null values is present

# %%
df.describe()
# Out:
#         Impressions     From Home  From Hashtags  From Explore   From Other  \
# count    119.000000    119.000000     119.000000    119.000000   119.000000
# mean    5703.991597   2475.789916    1887.512605   1078.100840   171.092437
# std     4843.780105   1489.386348    1884.361443   2613.026132   289.431031
# min     1941.000000   1133.000000     116.000000      0.000000     9.000000
# 25%     3467.000000   1945.000000     726.000000    157.500000    38.000000
# 50%     4289.000000   2207.000000    1278.000000    326.000000    74.000000
# 75%     6138.000000   2602.500000    2363.500000    689.500000   196.000000
# max    36919.000000  13473.000000   11817.000000  17414.000000  2547.000000
#
#              Saves    Comments      Shares       Likes  Profile Visits  \
# count   119.000000  119.000000  119.000000  119.000000      119.000000
# mean    153.310924    6.663866    9.361345  173.781513       50.621849
# ...

# %% [markdown]
# # Observations
# * Impressions: The reach of the post. It tells how many viewers have viewed the post
# * From Home: No of viewes who are already the followers and have viewed the post
# * From Hashtags: No of viewers who have seen thr post because of hashtag
# * From explore: No of viewers who randomly came across the post while scrolling
# * From Other: NO of viewers who have came across the post through other ways
# * Saves: No of viweres who have saved that post
# * Comments: No of viweres who have commented on that post
# * Shares: No of viweres who have shared that post
# * Likes: No of viweres who have liked that post
# * Profile Visits: No of viweres who havevisited the profile coz of that post
# * Follows: No of viweres who have newly followed.
#
#
# * In the above chart we can see the statistical information of all numerical columns

# %%
#Check the null values
df.isnull().sum()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %% [markdown]
# **there are no null values in any columns

# %% [markdown]
# # show null values with the help of heatmap

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# there is no null values im this dataframe as the whole graph is in one solid color.

# %% [markdown]
# # Duplicate Records

# %%
df[df.duplicated()]
# Out:
#     Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 82         5055       2017           2351           298         108    101
# 83         4002       3401            278           128          73    111
# 84         3169       1979            707           341          32    106
# 85         6168       2177           3450           153         296     82
# 86         2407       1338            655           276          39     40
# 87         3630       1747           1693            72          86    137
# 88         2826       2108            583            76          34     67
# 89         7407       2782           1938          2237         226    288
# 90        10386       4137           3551          2355         205    668
# 91         2998       1945            794            84         139     42
# 92         3052       2608            201           121          87     63
# ...

# %%
#Check duplicate values
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# there are 17 duplicate values in this dataframe

# %%
#Handle the duplicate values
df.drop_duplicates(inplace= True, ignore_index=True)

# %%
df.shape
# Out:
# (102, 13)

# %%
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
df['From Hashtags'].value_counts()
# Out:
# 362     2
# 411     2
# 1028    1
# 1423    1
# 4041    1
#        ..
# 139     1
# 1721    1
# 4604    1
# 771     1
# 4176    1
# Name: From Hashtags, Length: 100, dtype: int64

# %%
df.dtypes
# Out:
# Impressions        int64
# From Home          int64
# From Hashtags      int64
# From Explore       int64
# From Other         int64
# Saves              int64
# Comments           int64
# Shares             int64
# Likes              int64
# Profile Visits     int64
# Follows            int64
# Caption           object
# Hashtags          object
# dtype: object

# %% [markdown]
# This shows the data types of all the columns

# %%
df.size
# Out:
# 1326

# %% [markdown]
# There are total of 1428 elements in the dataframe

# %%
# Check Unique values

df.nunique()
# Out:
# Impressions       101
# From Home          97
# From Hashtags     100
# From Explore       95
# From Other         84
# Saves              84
# Comments           15
# Shares             28
# Likes              85
# Profile Visits     59
# Follows            29
# Caption            90
# Hashtags           54
# dtype: int64

# %% [markdown]
# # Check the wrong data or outliers

# %%
#Checking unique values

df["Impressions"].unique()
# Out:
# array([ 3920,  5394,  4021,  4528,  2518,  3884,  2621,  3541,  3749,
#         4115,  2218,  3234,  4344,  3216,  9453,  5055,  4002,  3169,
#         6168,  2407,  2064,  3973,  7281,  3052,  4628,  4082,  2766,
#         3924,  3015,  6666,  3854,  4355,  4343,  6108,  2523,  2327,
#         3990,  2191,  1941, 16062,  4998,  4289,  3880,  3786,  4298,
#         3630,  2826,  7407, 10386,  2998,  7018,  2941,  6432, 10667,
#         3988,  4978,  3388,  4467,  3246,  5072,  6339,  4239,  3454,
#         7571,  3333,  3818, 10933,  5058,  3601,  3480,  3525,  3606,
#         5542,  6559,  3623, 10493,  4446,  2957,  5538,  4681,  5273,
#         5409,  5323,  8001,  4150,  4609,  6348, 11068,  7231, 17396,
#         6814, 17713,  5563,  4842, 11149, 10206, 13700,  5731,  4139,
#        32695, 36919], dtype=int64)

# %%
#To analyse the distribution of each column
plt.figure(figsize=(10,5))
sns.histplot(df['Impressions'])
plt.title("Distribution of Impressions")
plt.show()

# %%
#To analyse the distribution of each column
plt.figure(figsize=(10,5))
sns.distplot(df['Impressions'])
plt.title("Distribution of Impressions")
plt.show()
# Out:
# C:\Users\Sapna\AppData\Local\Temp\ipykernel_2556\3290839816.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Impressions'])

# %% [markdown]
# There is more density of impressions from around 1900 to 11000
# But we are intrested in more no of impressions. So our area of focus is the tail of the graph
# Hardly few density of impression are in between 30000 - 40000.

# %%
df["From Home"].unique()
# Out:
# array([ 2586,  2727,  2085,  2700,  1704,  2046,  1543,  2071,  2384,
#         2609,  1597,  2414,  2168,  2524,  2525,  2017,  3401,  1979,
#         2177,  1338,  1304,  2415,  3065,  2608,  2406,  2195,  2275,
#         2541,  2244,  2034,  1977,  1975,  2879,  2278,  2679,  1659,
#         1774,  2123,  1308,  1466,  3144,  2331,  2746,  2207,  2632,
#         3050,  1747,  2108,  2782,  4137,  1945,  2569,  1716,  2812,
#         3152,  2125,  1910,  2508,  1780,  2190,  1711,  1663,  3717,
#         1502,  2357,  1570,  1323,  2509,  1782,  2225,  1179,  2106,
#         2454,  1926,  2597,  2252,  2673,  2643,  2000,  2261,  1807,
#         2032,  2517,  2099,  1855,  1817,  2816,  2449,  3813,  1658,
#         4439,  2371,  5185,  1923,  1133, 11815, 13473], dtype=int64)

# %%
#To analyse the distribution of each column
plt.figure(figsize=(10,5))
sns.histplot(df['From Home'])
plt.title("Distribution From Home")
plt.show()

# %%
#To analyse the distribution of each column
plt.figure(figsize=(10,5))
sns.distplot(df['From Home'])
plt.title("Distribution From Home")
plt.show()
# Out:
# C:\Users\Sapna\AppData\Local\Temp\ipykernel_2556\3772939553.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['From Home'])

# %% [markdown]
# There is more density of impressions from around 1500 to 3000
# But we are intrested in more no of viewers from home.
# So our area of focus is the tail of the graph
# Hardly few post have more no on viewers from home.

# %%
df.head(1)
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
#
#                                             Hashtags
# 0  #finance #money #business #investing #investme...

# %%
df['From Hashtags'].nunique()
#it shows the total unique value in the column
# Out:
# 100

# %%
df['From Hashtags'].unique()
#it shows the all unique value in the column
# Out:
# array([ 1028,  1838,  1188,   621,   255,  1214,   599,   628,   857,
#         1104,   411,   476,  1274,   212,  5799,  2351,   278,   707,
#         3450,   655,   362,   745,  1254,   201,  1260,  1248,  2975,
#          116,  1278,   771,  4604,  1721,   139,  1460,  2803,   796,
#          435,  1482,   809, 11817,  2195,   869,  1109,   616,   969,
#         1693,   583,  1938,  3551,   794,  4221,  1058,  2974,  6564,
#          802,  2249,  1018,  1880,   166,  3090,  4036,  2429,  1284,
#          841,  1423,   442,  6610,  2250,  1518,  1019,  1699,   183,
#         3212,  4041,  1527,  7761,  1590,   349,  2376,  1674,  2003,
#         2006,  2053,  5055,  1085,   911,  2660,  2986,  4156, 10008,
#         2769,  2141,   694,   747,  1624,  3041,  1368,  1538,  3147,
#         4176], dtype=int64)

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['From Hashtags'])
plt.title('distribution from Hashtags')
plt.show()
# Out:
# C:\Users\Sapna\AppData\Local\Temp\ipykernel_2556\2198109641.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['From Hashtags'])

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['From Hashtags'])
plt.title('Distribution from Hashtags:Histogram')
plt.show()

# %% [markdown]
# There is more density of viewers from Hashtag around 0 to 5000 But we are intrested in more no of viewers from home. So our area of focus is the tail of the graph Hardly few post have more no on viewers from hashtag.

# %%
df["From Explore"].unique()
# Out:
# array([  619,  1174,     0,   932,   279,   329,   333,   500,   248,
#          178,   162,   185,   673,   201,   208,   298,   128,   341,
#          153,   276,   249,   676,  2081,   121,   861,   541,    45,
#           51,   326,   115,    48,    60,  1239,   521,   562,    29,
#           59,   332,    37,   564,   318,   589,   199,   468,   181,
#           72,    76,  2237,  2355,    84,   796,   617,   545,   354,
#          244,   492,   360,    69,    36,   166,  1716,   182,   250,
#          623,   362,   174,   245,   446,   213,   158,   157,   192,
#          217,   412,   433,  1068,   988,   300,   463,   857,   737,
#         5634,   703,  5192,   900, 12389,  1135,  2036,  5762,  6000,
#         5352,  2266,  1367, 17414, 16444], dtype=int64)

# %%
df['From Explore'].nunique()
# Out:
# 95

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['From Explore'])
plt.title('Distribution From explore section')
plt.show()

# %% [markdown]
# There is more density of viewers from Explore is around 0 to 2500
# But we are intrested in more no of viewers from explore.
# So our area of focus is the tail of the graph
# Here we have bigger tail. This means we have less density of viewers who will explore the content

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['From Explore'])
plt.title('distribution from Explore section')
plt.show()
# Out:
# C:\Users\Sapna\AppData\Local\Temp\ipykernel_2556\523097711.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['From Explore'])

# %%
df['From Other'].nunique()
# Out:
# 84

# %%
df['From Other'].unique()
# Out:
# array([  56,   78,  533,   73,   37,   43,   25,   60,   49,   46,   15,
#          75,   40,  223,  794,  108,   32,  296,   39,   18,  748,   87,
#          26,   36,   65,    9,   34,   41,   23,   27,   21,   35,   17,
#         468,   24,  317,   64,   86,  226,  205,  139,   83,   48,   72,
#         187,   99,   44,   76,   50,  234, 1115,  148,  536,  334,  111,
#         167,  292,  300,  168,  655,  238,   69,  369,   63,  308,  114,
#         230,   74,  172,  792,  532,  154,  122,  309,  251,  128,  561,
#         310,   53,  117,   77,   33,  170, 2547], dtype=int64)

# %%
sns.lineplot(df['From Other'])
plt.title('distribution from Other section')
plt.xlabel('number of impressions')
plt.ylabel('Y axis')
plt.show()

# %%
sns.histplot(df['From Other'])
plt.title('distribution from Other section')
plt.xlabel('number of impressions')
plt.ylabel('Y axis')
plt.show()

# %%
df.head(1)
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
#
#                                             Hashtags
# 0  #finance #money #business #investing #investme...

# %%
# Feature engineering

#To find out the engagement rate
df['Engagement Rate']= (df['Saves']+df['Likes']+df['Comments']+df["Shares"]+df['Profile Visits'])/df['Impressions']

# %%
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
df[df["Engagement Rate"]>0.10]
# Out:
#     Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 45         4298       3050            969           181          64    263
# 49        10386       4137           3551          2355         205    668
# 64         7571       3717            841          1716        1115    421
# 81         5273       2673           2003           433         114    318
# 82         5409       2643           2006          1068         230    393
# 91         6814       2816           2769           900         128    469
#
#     Comments  Shares  Likes  Profile Visits  Follows  \
# 45         6      19    225              21        4
# 49         8      41    328              42       38
# 64         7      12    269              50       46
# 81         9      22    250              25       10
# 82        10      27    275              38       14
# 91         8      22    249              24       16
#
#                                               Caption  \
# ...

# %%
#To find the correlation between each col
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")
plt.show()
# Out:
# C:\Users\Sapna\AppData\Local\Temp\ipykernel_2556\4262406096.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")

# %% [markdown]
# The heatmap shows the coorelation between each feature and we can infere following from the map:
# * Impression have good coorelation with from home, from explore, likes, follows. In other words if you focus on these features the chancs of increasing the reach is more.
# * Hashtags plays a vital role when you like a post or visit a profile based on post you see
# * Through a random scrolling post there are high chances that a viewer will directly follow your profile
# * A contet is likely to be saved, shared ad liked if it is more engaging.
# * Here comment dosent seems to play major role in getting the reach.
# * If  content is getting more saves then the chances of getting followers is more as the engagement rate is high.
# * A viwere might visit your profile frequently is he follws you and likes the type of content your are posting even if the content dosent seem engaging for more viewers.
# * In order to increase your reach you have to increase your followers and get more followers one should focus on getting more impressions from home viewers, one should get more no of likes and profile visits. This might lead to pop up your content while surfing randomly and ;eaf to increaase the reach.

# %%
#Analyse the trend or pattern of features
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Impressions'],'g-',linewidth=0.9,label="Impression")
plt.xlabel("Index")
plt.ylabel("Impressions")
plt.title("Trend of Impressions")
plt.show()

# %% [markdown]
# As we have seen earlier only few people have engaging content and now as per the trend only few have higher impressions.
# Below is the details of impressions above 10000

# %%
df[df["Impressions"]>10000]
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 40         16062       3144          11817           564         468    252
# 49         10386       4137           3551          2355         205    668
# 54         10667       3152           6564           617         187    219
# 67         10933       3152           6610           623         334    225
# 76         10493       2106           7761           248         238     99
# 88         11068       2099           2986          5634         122    214
# 90         17396       1817          10008          5192         251    285
# 92         17713       2449           2141         12389         561    504
# 95         11149       4439            747          5762          53    273
# 96         10206       2371           1624          6000         117    182
# 97         13700       5185           3041          5352          77    573
# ...

# %% [markdown]
# As we can see only the last 2 records have highest impressions. But they dont have a good engagemnet ratio.
# Only the 49th record have higher enagement ratio and comparatively higher impressions.

# %%
#Analyse the trend or pattern of features
plt.figure(figsize=(10,5))
plt.plot(df.index,df['From Home'],'b-',linewidth=0.9,label="Home")
#b stands for blue color
#plt.plot(df.index,df['From Hashtags'],'b-',linewidth=0.9,label="Hashtags")
#plt.plot(df.index,df['From Explore'],'r-',linewidth=0.9,label="Explore")
plt.xlabel("Index")
plt.ylabel("From home")
plt.legend()
plt.title("Trend of impression from Home")
plt.show()

# %%
df[df["From Home"]>4000]
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 49         10386       4137           3551          2355         205    668
# 95         11149       4439            747          5762          53    273
# 97         13700       5185           3041          5352          77    573
# 100        32695      11815           3147         17414         170   1095
# 101        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# 49          8      41    328              42       38
# 95          4      13    210              61       58
# 97          2      38    373              73       80
# 100         2      75    549             148      214
# 101         5      26    443             611      228
#
#                                                Caption  \
# 49   Here are some of the best websites that you ca...
# 95   Python is one of the best programming language...
# ...

# %%
#Analyse the trend or pattern of features
plt.figure(figsize=(10,5))
plt.plot(df.index,df['From Hashtags'],'y-',linewidth=0.9,label="Hashtags")
#y stand for yellow color
plt.xlabel("Index")
plt.ylabel("From Hashtags")
plt.legend()
plt.title("Trend of impression from Hashtags")
plt.show()

# %%
#Analyse the trend or pattern of features
plt.figure(figsize=(10,5))
plt.plot(df.index,df['From Explore'],'r-',linewidth=0.9,label="Explore")
plt.xlabel("Index")
plt.ylabel("From explore")
plt.legend()
plt.title("Trend of impression from Explore")
plt.show()

# %%
df[df['Profile Visits']>200]
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 40         16062       3144          11817           564         468    252
# 54         10667       3152           6564           617         187    219
# 67         10933       3152           6610           623         334    225
# 90         17396       1817          10008          5192         251    285
# 96         10206       2371           1624          6000         117    182
# 101        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# 40          6      20    416             330       94
# 54         13      15    297             306       74
# 67         13      15    301             347       94
# 90          7       7    416             467      260
# 96         10      17    172             237      100
# 101         5      26    443             611      228
#
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Profile Visits'],'m-',linewidth=0.9, label='Visits')
plt.xlabel("Index")
plt.ylabel("From Profile Visits")
plt.legend()
plt.title("Trend of impression from profile visits")
plt.show()

# %%
#Compaision for reach
sns.barplot(x= ['From Home','From Hashtags','From Explore','From Other'],
            y= [df["From Home"].mean(),df['From Hashtags'].mean(),df['From Explore'].mean(),df['From Other'].mean()])
plt.title('Reach Comparision')
plt.xlabel('Reach from diffrent features')
plt.ylabel('Reach')
plt.show()

# %% [markdown]
# Viewers from home and from hashtags have more contibution in increasing the reach.
#
# # Let us see some trending hashtags

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Wordclouds to find highlighted hashtags
from wordcloud import WordCloud
plt.figure(figsize=(10,8))
hashtag = " ".join(df['Hashtags'].tolist())
wordcloud = WordCloud(width=1000,height=500).generate(hashtag)
plt.imshow(wordcloud)
plt.title("Wordcloud for hashtags")
plt.show()

# %%
#Comparision for like share comment save follow
sns.barplot(x= ["Save","Comment","Share","Likes","Profile Visits","Follow"],
            y= [df["Saves"].mean(),df['Comments'].mean(),df['Shares'].mean(),df['Likes'].mean(),df['Profile Visits'].mean(),df['Follows'].mean()])
plt.show()

# %% [markdown]
# Save and Likes here have major values. So if a post gets shared or saved then the chances of increasing the reach increases.
# This tells us that the content should be savable and likable by audience.

# %% [markdown]
# # Finding the percentages of reach for each feature

# %%
home_reach = (df['From Home'].sum()/df['Impressions'].sum())*100
home_reach
# Out:
# 42.17574759963303

# %%
hashtag_reach = (df['From Hashtags'].sum()/df['Impressions'].sum())*100
hashtag_reach
# Out:
# 33.246614315096394

# %%
explore_reach = (df['From Explore'].sum()/df['Impressions'].sum())*100
explore_reach
# Out:
# 19.90739667409657

# %%
save_reach = (df['Saves'].sum()/df['Impressions'].sum())*100
save_reach
# Out:
# 2.64429525755714

# %%
Comments_reach = (df['Comments'].sum()/df['Impressions'].sum())*100
Comments_reach
# Out:
# 0.10730857508122663

# %%
share_reach = (df['Shares'].sum()/df['Impressions'].sum())*100
share_reach
# Out:
# 0.157154070605068

# %%
like_reach = (df['Likes'].sum()/df['Impressions'].sum())*100
like_reach
# Out:
# 2.986755339760808

# %%
visitors_reach = (df['Profile Visits'].sum()/df['Impressions'].sum())*100
visitors_reach
# Out:
# 0.9233836645878389

# %%
followers_reach = (df['Follows'].sum()/df['Impressions'].sum())*100
followers_reach
# Out:
# 0.38551599195848085

# %%
#Comparision for like share comment save follow
plt.pie(labels= ["Home","Hashtag","Explore","Save","Comment","Share","Likes","Profile Visits","Follow"],
        x= [home_reach,hashtag_reach,explore_reach,save_reach,Comments_reach,
                share_reach,like_reach, visitors_reach,followers_reach],autopct='%1.0f%%',explode = [0,0,0,0.5,0.9,0.5,0.5,0.7,0.5])
#plt.xticks(rotation=90)
plt.show()
