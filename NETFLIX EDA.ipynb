# %% [markdown]
# # NETFLIX DATA ANALYSIS

# %%
import pandas as pd       #to import out dataset we need to import pandas library
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Sapna\Desktop\netflix_titles.csv")     # r is to remove the unicode error

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# This show the top 5 rows by default

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# tail() func shows the rows from below , by default is shows bottom 5 rows

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# shows the number of rows and columns in dataset

# %%
df.size
# Out:
# 105684

# %% [markdown]
# this shows the no. of total values in dataset

# %%
df.columns         #shows the names of the columns in dataset
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.index          #shows the number of rows and their increment and start number.
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# #### we see that except for release year all other columns have datatype of object.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# #### info() function shows the basic infor of the dataset like, total columns, column names and datatype, null values, storage occupoed, rangeindex(rows)

# %% [markdown]
# ## TASK 1-find the duplicates records if any and remove it

# %%
df.shape                # for reference
# Out:
# (8807, 12)

# %%
df.duplicated()          #this shows the duplicates in boolen(true or false)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### This gives us the total of all duplicate values , here we see there are no duplicate values
# df[df.duplicated()] this function woould filter out all the duplicate records
#
# df.drop_duplicates( inplace=True) this fucntion would drop all the duplicates from the dataset,to permanently change the dataset we use inplace=true

# %% [markdown]
# ## Task-2 Is there any null values present in any  column show with the help of heatmap

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %% [markdown]
# All the places where its showing true means it has null values.

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# This shows the total null values in all the columns, we can see column 'director' has highest null values aorund 2634 null same cast has 825 etc.

# %% [markdown]
# to use the heatmap we have to import the seaborn library

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## from this heatmap we can see that column director has highest null values .

# %% [markdown]
# # TASK 3 - FILTERING QUESTIONS

# %% [markdown]
# ### 1.For 'House of cards' who is the director and what is the what is the show id.

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df['title']                    # this show all the elements of a particular column
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
df['title'].isin(['House of Cards'])
# this shows the vales in true and false , to get the result in desired way we have to mention the dataframe name in sqr barces
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: title, Length: 8807, dtype: bool

# %%
df[df['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# here we can see the show id is s1060 and the director is not mentioned.

# %%
df[df['title'].str.contains('House of Cards')]       # another way of getting the same output
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ## 2. In which year highest no of shows and movies were released show with bar graph.

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# here we see that the datatype of release year is in int we have to convert in datetime format.

# %% [markdown]
# ### Here we can see new column has been created with the name date_t

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df['release_year'].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %% [markdown]
# From here we can see that 2018 has maximum number of shows released.

# %%
df['release_year'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## 3.How many tv shoes and movies are there in the dataset show with bar graph?

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df.groupby('type').count()                             # to group all unique items in the column
# Out:
#          show_id  title  director  cast  country  date_added  release_year  \
# type
# Movie       6131   6131      5943  5656     5691        6131          6131
# TV Show     2676   2676       230  2326     2285        2666          2676
#
#          rating  duration  listed_in  description
# type
# Movie      6129      6128       6131         6131
# TV Show    2674      2676       2676         2676

# %%
df.groupby('type').type.count()                       # # to group all unique items in the column and show thir count.
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# Here we can see that there are total of 6131 movies and 2676 tv shows

# %%
df.groupby('type').type.count().plot(kind='bar')
# Out:
# <Axes: xlabel='type'>

# %% [markdown]
# ## 4. show all the movies released in 2000

# %%
df[(df['type']=='Movie') & (df['release_year']==2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %% [markdown]
# #THIS FILTER APPLIES TWO CONDITION .

# %% [markdown]
# ##  4.Show all the titles of Tv shows released in india only

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df[(df['type']=='TV Show') &  (df['country']=='India')].title
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# This shows all the titles of TV shows released in india.

# %% [markdown]
# ## 5. Show top 10 directors whogave maximum shows and movies to netflix.

# %%
df['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# ### we can see that Rajiv Chilaka has made highest number of  movies/shows

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# ## 6. SHOW ALL THE RECORDS WHERE type is movie and listen_in is comedies or country is united kingdom

# %%
df[(df['type']=='Movie') & (df['listed_in']=='Comedies') |  (df['country']=='United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %% [markdown]
# There are total of 521 records satisfying this criteria

# %%
df[(df['type']=='Movie') & (df['listed_in']=='Comedies')]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %% [markdown]
# ## 7. In how many movies or show tom cruise was cast.

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df[df['cast']=='Justin Deeley']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# there is no record in dataframe where the cast is only justin deeley.

# %%
# df[df['cast'].str.contains('Justin Deeley')]      
# this func doesnt work with null values so we will remove all the null values

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df[df['cast'].str.contains('Justin Deeley')]
# Out:
#      show_id   type             title          director  \
# 8608   s8609  Movie  Total Frat Movie  Warren P. Sonoda
#
#                                                    cast        country  \
# 8608  Justin Deeley, Alex House, Steven Yaffee, Rebe...  United States
#
#              date_added  release_year rating duration listed_in  \
# 8608  December 19, 2016          2016     NR   94 min  Comedies
#
#                                             description
# 8608  A disbanded fraternity tries to get their act ...

# %% [markdown]
# ## 7. What are the diffrent types of rating defined in netflix

# %%
df.rating.unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G', 'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df.rating.nunique()                   #TOtal 14 kinds of ratings are there.
# Out:
# 14

# %% [markdown]
# ## 8. How many movies got the TV-14 rating ion Canada.?

# %%
df[(df['type']=='Movie') & (df['rating']=='TV-14') & (df['country']=='Canada')].shape
# Out:
# (10, 12)

# %% [markdown]
# #### There are total 10 movies .

# %%
df[(df['type']=='Movie') & (df['rating']=='TV-14') & (df['country']=='Canada')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# 157                       Danishka Esterhazy
# 2769                  Ellen Page, Ian Daniel
# 3424                     Jean-François Blais
# 5973                         Michael Kennedy
# ...

# %% [markdown]
# #### These are the deatils of all the movies with tv-14 ratings in canada

# %% [markdown]
# ## 9.How many TV show got the R rating after year 2018

# %%
df[(df['type']=='TV Show') & (df['release_year']>2018) & (df['rating']=='R')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# #### there are no tv show after 2018 with rating R

# %%
df[(df['type']=='TV Show') & (df['release_year']>2018)]
# Out:
#      show_id     type                                 title  \
# 8         s9  TV Show         The Great British Baking Show
# 198     s199  TV Show  King of Boys: The Return of the King
# 273     s274  TV Show                         Gone for Good
# 276     s277  TV Show                               Valeria
# 297     s298  TV Show                              Navarasa
# ...      ...      ...                                   ...
# 3653   s3654  TV Show      Comedians in Cars Getting Coffee
# 3719   s3720  TV Show                               Bolívar
# 3860   s3861  TV Show              Crime Diaries: Night Out
# 3928   s3929  TV Show                               Persona
# 6024   s6025  TV Show                             7 (Seven)
#
#                                                director  \
# 8                                       Andy Devonshire
# 198                                        Kemi Adetiba
# 273                                  Juan Carlos Medina
# ...

# %% [markdown]
# #### These are the details of tv show after 2018

# %% [markdown]
# # 10. What is the maximum duration of netflis tv show/moivie

# %%
df.duration.unique()
# Out:
# array(['125 min', '9 Seasons', '104 min', '127 min', '166 min', '103 min',
#        '97 min', '106 min', '96 min', '124 min', '116 min', '98 min',
#        '91 min', '115 min', '122 min', '99 min', '88 min', '100 min',
#        '102 min', '93 min', '95 min', '85 min', '83 min', '182 min',
#        '147 min', '90 min', '128 min', '143 min', '119 min', '114 min',
#        '118 min', '108 min', '117 min', '121 min', '142 min', '113 min',
#        '154 min', '120 min', '82 min', '94 min', '109 min', '101 min',
#        '105 min', '86 min', '229 min', '76 min', '89 min', '110 min',
#        '156 min', '112 min', '129 min', '107 min', '1 Season', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '145 min', '92 min',
#        '2 Seasons', '64 min', '59 min', '111 min', '87 min', '148 min',
#        '189 min', '141 min', '130 min', '7 Seasons', '68 min', '131 min',
#        '126 min', '155 min', '123 min', '84 min', '4 Seasons', '13 min',
# ...

# %% [markdown]
# #### We see the datatype is object and there are diffrent type of duration some in seasons and some in hr and minutes.

# %%
df.duration.nunique()
# Out:
# 198

# %% [markdown]
# ### Now we will change the datatype by splitting te column into two.

# %%
df[['minutes','unit']]=df['duration'].str.split(' ',expand=True)

# %%
df.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
df.minutes.max()
# Out:
# '99'

# %%
df.minutes.min()
# Out:
# '1'

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# minutes         object
# unit            object
# dtype: object

# %% [markdown]
# ## Which individual country has the highest tv shows.

# %%
df_tvshow =df[df['type']=='TV Show']

# %%
df_tvshow.head(2)
# Out:
#     show_id     type                                 title         director  \
# 8        s9  TV Show         The Great British Baking Show  Andy Devonshire
# 198    s199  TV Show  King of Boys: The Return of the King     Kemi Adetiba
#
#                                                   cast         country  \
# 8    Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  United Kingdom
# 198  Sola Sobowale, Toni Tones, Richard Mofe-Damijo...         Nigeria
#
#              date_added  release_year rating   duration  \
# 8    September 24, 2021          2021  TV-14  9 Seasons
# 198     August 27, 2021          2021  TV-MA   1 Season
#
#                                              listed_in  \
# 8                         British TV Shows, Reality TV
# 198  Crime TV Shows, International TV Shows, TV Dramas
#
#                                            description minutes     unit
# 8    A talented batch of amateur bakers face off in...       9  Seasons
# ...

# %%
df_tvshow.country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# India                                                             7
# Taiwan                                                            7
# France                                                            5
# Turkey                                                            5
# Thailand                                                          5
# Nigeria                                                           4
# Brazil                                                            4
# Canada                                                            3
# United States, Canada                                             2
# ...

# %% [markdown]
# #### Here we can see United states has the most number of tv shows.

# %%
df[df['type']=='TV Show'].country.value_counts()           # alternate way.
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# India                                                             7
# Taiwan                                                            7
# France                                                            5
# Turkey                                                            5
# Thailand                                                          5
# Nigeria                                                           4
# Brazil                                                            4
# Canada                                                            3
# United States, Canada                                             2
# ...

# %% [markdown]
# ## 10. How to sort the dataset by year

# %%
df.sort_values(by='release_year').head(2)
# Out:
#      show_id   type                 title  \
# 8205   s8206  Movie  The Battle of Midway
# 8640   s8641  Movie      Tunisian Victory
#
#                                                director  \
# 8205                                          John Ford
# 8640  Frank Capra, John Huston, Hugh Stewart, Roy Bo...
#
#                            cast                        country  \
# 8205  Henry Fonda, Jane Darwell                  United States
# 8640           Burgess Meredith  United States, United Kingdom
#
#           date_added  release_year rating duration  \
# 8205  March 31, 2017          1942  TV-14   18 min
# 8640  March 31, 2017          1944  TV-14   76 min
#
#                           listed_in  \
# 8205  Classic Movies, Documentaries
# 8640  Classic Movies, Documentaries
#
#                                             description minutes unit
# 8205  Director John Ford captures combat footage of ...      18  min
# ...

# %% [markdown]
# #### This sorts the data in ascending order.

# %%
df.sort_values(by='release_year' , ascending = False).head(5)
# Out:
#      show_id     type                title  \
# 1184   s1185    Movie  The Yin Yang Master
# 910     s911    Movie              Monster
# 297     s298  TV Show             Navarasa
# 299     s300    Movie            The Swarm
# 300     s301    Movie                 Vivo
#
#                                                director  \
# 1184                                          Li Weiran
# 910                                     Anthony Mandler
# 297   Bejoy Nambiar, Priyadarshan, Karthik Narain, V...
# 299                                      Just Philippot
# 300                      Kirk DeMicco, Brandon Jeffords
#
#                                                    cast  \
# 1184  Chen Kun, Zhou Xun, Qu Chuxiao, Shen Yue, Will...
# 910   Kelvin Harrison Jr., Jennifer Hudson, Jeffrey ...
# 297   Suriya, Vijay Sethupathi, Revathy, Prakash Raj...
# 299   Suliane Brahim, Sofian Khammes, Marie Narbonne...
# 300   Lin-Manuel Miranda, Ynairaly Simo, Zoe Saldana...
#
# ...

# %% [markdown]
# #### This sorts the dataset by latest year

# %% [markdown]
# #### So we have analysed the Netflix dataset by first cleaning the data and running some basic codes to know the datastructure, columns,rows,datatypes, duplicates,null values. WE did some cleaning to remove null values and duplicates and also plotted some bar graph to see the pattern and comaopre the values. WE did some data filteration too to get the desired output.
