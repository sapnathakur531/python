# %% [markdown]
# # Apple Sales Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Sapna\Desktop\Apple.csv")

# %%
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         62 non-null     object
#  1   Product URL          62 non-null     object
#  2   Brand                62 non-null     object
#  3   Sale Price           62 non-null     int64
#  4   Mrp                  62 non-null     int64
#  5   Discount Percentage  62 non-null     int64
#  6   Number Of Ratings    62 non-null     int64
#  7   Number Of Reviews    62 non-null     int64
#  8   Upc                  62 non-null     object
#  9   Star Rating          62 non-null     float64
#  10  Ram                  62 non-null     object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 5.5+ KB

# %% [markdown]
#  From df.info function we can see that there are total of 11 columns and 62 rows, out of 11 columns ,5 have object datatype and ine has float datatype others int64.

# %%
df.isnull().sum()
# Out:
# Product Name           0
# Product URL            0
# Brand                  0
# Sale Price             0
# Mrp                    0
# Discount Percentage    0
# Number Of Ratings      0
# Number Of Reviews      0
# Upc                    0
# Star Rating            0
# Ram                    0
# dtype: int64

# %% [markdown]
# here we can see there are no null values in any of the columns.

# %%
df.describe()
# Out:
#           Sale Price            Mrp  Discount Percentage  Number Of Ratings  \
# count      62.000000      62.000000            62.000000          62.000000
# mean    80073.887097   88058.064516             9.951613       22420.403226
# std     34310.446132   34728.825597             7.608079       33768.589550
# min     29999.000000   39900.000000             0.000000         542.000000
# 25%     49900.000000   54900.000000             6.000000         740.000000
# 50%     75900.000000   79900.000000            10.000000        2101.000000
# 75%    117100.000000  120950.000000            14.000000       43470.000000
# max    140900.000000  149900.000000            29.000000       95909.000000
#
#        Number Of Reviews  Star Rating
# count          62.000000    62.000000
# mean         1861.677419     4.575806
# std          2855.883830     0.059190
# min            42.000000     4.500000
# 25%            64.000000     4.500000
# 50%           180.000000     4.600000
# ...

# %%
df.describe().T
# Out:
#                      count          mean           std      min      25%  \
# Sale Price            62.0  80073.887097  34310.446132  29999.0  49900.0
# Mrp                   62.0  88058.064516  34728.825597  39900.0  54900.0
# Discount Percentage   62.0      9.951613      7.608079      0.0      6.0
# Number Of Ratings     62.0  22420.403226  33768.589550    542.0    740.0
# Number Of Reviews     62.0   1861.677419   2855.883830     42.0     64.0
# Star Rating           62.0      4.575806      0.059190      4.5      4.5
#
#                          50%       75%       max
# Sale Price           75900.0  117100.0  140900.0
# Mrp                  79900.0  120950.0  149900.0
# Discount Percentage     10.0      14.0      29.0
# Number Of Ratings     2101.0   43470.0   95909.0
# Number Of Reviews      180.0    3331.0    8161.0
# Star Rating              4.6       4.6       4.7

# %%
df.describe(include='object')
# Out:
#                              Product Name  \
# count                                  62
# unique                                 62
# top     APPLE iPhone 8 Plus (Gold, 64 GB)
# freq                                    1
#
#                                               Product URL  Brand  \
# count                                                  62     62
# unique                                                 62      1
# top     https://www.flipkart.com/apple-iphone-8-plus-g...  Apple
# freq                                                    1     62
#
#                      Upc   Ram
# count                 62    62
# unique                62     4
# top     MOBEXRGV7EHHTGUH  4 GB
# freq                   1    29

# %%
df.shape
# Out:
# (62, 11)

# %%
df.columns
# Out:
# Index(['Product Name', 'Product URL', 'Brand', 'Sale Price', 'Mrp',
#        'Discount Percentage', 'Number Of Ratings', 'Number Of Reviews', 'Upc',
#        'Star Rating', 'Ram'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=62, step=1)

# %% [markdown]
# There are 63 Rows starting from 0 rows.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values in numerical columns

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
df.nunique()
# Out:
# Product Name           62
# Product URL            62
# Brand                   1
# Sale Price             24
# Mrp                    22
# Discount Percentage    16
# Number Of Ratings      19
# Number Of Reviews      18
# Upc                    62
# Star Rating             3
# Ram                     4
# dtype: int64

# %%
df['Product Name'].unique()
# Out:
# array(['APPLE iPhone 8 Plus (Gold, 64 GB)',
#        'APPLE iPhone 8 Plus (Space Grey, 256 GB)',
#        'APPLE iPhone 8 Plus (Silver, 256 GB)',
#        'APPLE iPhone 8 (Silver, 256 GB)', 'APPLE iPhone 8 (Gold, 256 GB)',
#        'APPLE iPhone 8 Plus (Silver, 64 GB)',
#        'APPLE iPhone 8 Plus (Space Grey, 64 GB)',
#        'APPLE iPhone 8 (Space Grey, 256 GB)',
#        'APPLE iPhone XS Max (Silver, 64 GB)',
#        'Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)',
#        'Apple iPhone XR (Black, 64 GB) (Includes EarPods, Power Adapter)',
#        'Apple iPhone XR (Coral, 128 GB) (Includes EarPods, Power Adapter)',
#        'Apple iPhone XR (Black, 128 GB) (Includes EarPods, Power Adapter)',
#        'Apple iPhone XR (White, 128 GB) (Includes EarPods, Power Adapter)',
#        'APPLE iPhone 11 Pro Max (Gold, 256 GB)',
#        'APPLE iPhone 11 Pro Max (Gold, 64 GB)',
#        'APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)',
# ...

# %% [markdown]
# ##### This shows all the unique values in the columns

# %%
df['Discount Percentage'].unique()
# Out:
# array([ 0, 20, 16, 29, 15, 17, 18,  6, 13, 14, 10,  7, 11,  8, 24, 22],
#       dtype=int64)

# %% [markdown]
# #### This shows all the unique disc values

# %%
df.max()
# Out:
# Product Name           Apple iPhone XR (White, 128 GB) (Includes EarP...
# Product URL            https://www.flipkart.com/apple-iphone-xs-max-s...
# Brand                                                              Apple
# Sale Price                                                        140900
# Mrp                                                               149900
# Discount Percentage                                                   29
# Number Of Ratings                                                  95909
# Number Of Reviews                                                   8161
# Upc                                                     MOBFWQ6BYYV3FCU7
# Star Rating                                                          4.7
# Ram                                                                 6 GB
# dtype: object

# %% [markdown]
# ##### From here we can see that Apple iphone XR(white,128 GB) has maximum sales, similarly we see maximum rating is of 4.7, discount percentage is of 29.

# %%
df.min()
# Out:
# Product Name                             APPLE iPhone 11 (Black, 128 GB)
# Product URL            https://www.flipkart.com/apple-iphone-11-black...
# Brand                                                              Apple
# Sale Price                                                         29999
# Mrp                                                                39900
# Discount Percentage                                                    0
# Number Of Ratings                                                    542
# Number Of Reviews                                                     42
# Upc                                                     MOBEXRGV7EHHTGUH
# Star Rating                                                          4.5
# Ram                                                                 2 GB
# dtype: object

# %% [markdown]
# From here we can see that Apple iphone 11(Black,128 GB) has minimum sales, similarly we see minimum rating is of 4.5, discount percentage is of 0

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Sale Price'])
plt.title('Distribution Of Impressions')
plt.show()

# %%
#import warnings
#from warnings import ignore_warning=True

# %%
plt.figure(figsize=(8,5))
sns.distplot(df['Sale Price'])
plt.title('Distribution Of Sale price')
plt.show()
# Out:
# C:\Users\Sapna\AppData\Local\Temp\ipykernel_972\1493877664.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sale Price'])

# %%
plt.figure(figsize=(8,5))
sns.distplot(df['Discount Percentage'])
plt.title('Distribution Of Discount Percentage')
plt.show()
# Out:
# C:\Users\Sapna\AppData\Local\Temp\ipykernel_972\666184544.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Discount Percentage'])

# %% [markdown]
# Maximum value disc 29% , max number of disc 10%, min value of disc 0%

# %%
plt.figure(figsize=(8,5))
sns.distplot(df['Number Of Ratings'])
plt.title('Distribution Of Number Of Ratings')
plt.show()
# Out:
# C:\Users\Sapna\AppData\Local\Temp\ipykernel_972\2268973561.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Number Of Ratings'])

# %% [markdown]
# # comparision for sales and Mrp

# %%
sns.barplot(x=['Sale Price','Mrp'],
           y=[df['Sale Price'].mean(), df['Mrp'].mean()])
plt.show()

# %%
df.head(1)
# Out:
#                         Product Name  \
# 0  APPLE iPhone 8 Plus (Gold, 64 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
#
#                 Upc  Star Rating   Ram
# 0  MOBEXRGV7EHHTGUH          4.6  2 GB

# %% [markdown]
# ######  doubt:
# how to compare the sale price and mrp in line graph to see the pattern or trends.

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Sale Price'],df['Mrp'], 'm-', linewidth=1.5, label='MRP')
plt.xlabel('sales and Mrp')
plt.ylabel('values')
plt.title('Sales & MRP')
plt.legend()
plt.show()

# %%
df[df['Sale Price']>90000]
# Out:
#                                         Product Name  \
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 19          APPLE iPhone 11 Pro (Space Grey, 512 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 21      APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# 22          APPLE iPhone 11 Pro (Space Grey, 256 GB)
# 24              APPLE iPhone 12 Pro (Silver, 512 GB)
# 25    APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# 27            APPLE iPhone 12 Pro (Graphite, 256 GB)
# 30            APPLE iPhone 12 Pro (Graphite, 128 GB)
# 31        APPLE iPhone 12 Pro Max (Graphite, 256 GB)
# 32        APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 37          APPLE iPhone 12 Pro Max (Silver, 128 GB)
# 39            APPLE iPhone 12 Pro Max (Gold, 128 GB)
# 41        APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# ...

# %%
df[df['Star Rating']>4.6]
# Out:
#                                         Product Name  \
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 14  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# 15  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 20  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 14  131900                    0               1078                101
# ...

# %%
filtered_df = df[(df['Sale Price']>40000) &(df['Sale Price']<80000)]
print(filtered_df)
# Out:
#                                          Product Name  \
# 0                   APPLE iPhone 8 Plus (Gold, 64 GB)
# 3                     APPLE iPhone 8 (Silver, 256 GB)
# 4                       APPLE iPhone 8 (Gold, 256 GB)
# 5                 APPLE iPhone 8 Plus (Silver, 64 GB)
# 6             APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 7                 APPLE iPhone 8 (Space Grey, 256 GB)
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...
# 13  Apple iPhone XR (White, 128 GB) (Includes EarP...
# 18        APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...
# 26               APPLE iPhone 12 Mini (White, 128 GB)
# 28                APPLE iPhone 12 Mini (White, 64 GB)
# 29                    APPLE iPhone 12 (White, 128 GB)
# 33               APPLE iPhone 12 Mini (Black, 128 GB)
# ...

# %%
df[df['Sale Price']<40000]
# Out:
#                                          Product Name  \
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...
# 52                     APPLE iPhone SE (White, 64 GB)
# 53                    APPLE iPhone SE (Black, 128 GB)
# 54                    APPLE iPhone SE (White, 128 GB)
# 55                      APPLE iPhone SE (Red, 128 GB)
# 57                     APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 10  https://www.flipkart.com/apple-iphone-xr-black...  Apple       39999
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 53  https://www.flipkart.com/apple-iphone-se-black...  Apple       34999
# 54  https://www.flipkart.com/apple-iphone-se-white...  Apple       34999
# 55  https://www.flipkart.com/apple-iphone-se-red-1...  Apple       34999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
#
# ...

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")
plt.show()
# Out:
# C:\Users\Sapna\AppData\Local\Temp\ipykernel_972\799783303.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")

# %%
df.head(2)
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
#
#                 Upc  Star Rating   Ram
# 0  MOBEXRGV7EHHTGUH          4.6  2 GB
# 1  MOBEXRGVAC6TJT4F          4.6  2 GB

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=['Sale Price','Number Of Ratings'],
           y=[df['Sale Price'].mean(),
            df['Number Of Ratings'].mean()])
plt.title('sales and Ratings')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
